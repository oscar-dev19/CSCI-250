# %%
"""
Simple Stock Analysis Program from US Based Stock Market.

Author: Oscar Lopez
Email: oscarl.developer@gmail.com
Version:
"""

import matplotlib.pyplot as plt
import pandas as pd

#Reading data 
nasdaq_url = "https://old.nasdaq.com/screening/companies-by-industry.aspx?exchange=NASDAQ&render=download"
nyse_url = "https://old.nasdaq.com/screening/companies-by-industry.aspx?exchange=NYSE&render=download"
amex_url = "https://old.nasdaq.com/screening/companies-by-industry.aspx?exchange=AMEX&render=download"

# Setting column names
column_names = ['Symbol', 'Name', 'LastSale', 'MarketCap', 'ADR_TSO', 'IPOyear', 'Sector', 'Industry', 'Summary_Quote']

# Setting up data frames from urls
nasdaq_data = pd.read_csv(nasdaq_url, header=None, names=column_names, skiprows=0)
#nyse_data = pd.read_csv(nyse_url, header=None, names=column_names, skiprows=1)
#amex_data = pd.read_csv(amex_url, header=None, names=column_names, skiprows=1)

print(nasdaq_data)
# Out:
#                                         Symbol      Name        LastSale  \
# Symbol                                    Name  LastSale       MarketCap
# TXG                         10x Genomics, Inc.     58.63    5590350565.8
# YI                                   111, Inc.       4.8      90073281.6
# PIH     1347 Property Insurance Holdings, Inc.      4.59     27598586.76
# PIHPP   1347 Property Insurance Holdings, Inc.      25.4        17780000
# TURN                  180 Degree Capital Corp.      2.06     64110417.72
# FLWS                   1-800 FLOWERS.COM, Inc.     14.06    907543628.66
# BCOW           1895 Bancorp of Wisconsin, Inc.     9.615    46889249.355
# FCCY             1st Constitution Bancorp (NJ)     19.02    164602332.42
# SRCE                    1st Source Corporation     51.06   1303827924.72
# VNET                      21Vianet Group, Inc.      8.01    500624431.29
# TWOU                                  2U, Inc.     17.59   1114060732.69
# ...
