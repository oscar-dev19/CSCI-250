# %%
import matplotlib.pyplot as plt


def plot_data(list_countries, csv_file='gdp.csv'):
    """
    Simple function that plots from a given csv file of gdp data
    including country name and year.
    
    Parameters:
    (String)csv_file : name of file to be parsed and plotted.
    (list)list_countries : list of countries whose data will be plotted.
    """
    countries_plotted = list()
    values = list()
    year = list()
    
    try:
        fopen = open(csv_file)        
    except FileNotFoundError:
        print('ERROR: csv file not found! Cannot plot any data.')
        return None
    
    #ignore header file
    fopen.readline()
    
    for line in fopen:
        line = line.strip('\n')
        data = line.split(',')
        
        #Some data has an extra comma for 'The'.
        #In case this happens data must be parsed differently.
        if data[1] == ' The"':
            #Removing unnecessary quotes and spacing on country name
            data[1] = data[1].replace('"', '')
            data[0] = data[0].replace('"', '')
            data[1] = data[1].replace(' ', '')
            
            if data[1] + ' ' + data[0] in list_countries:
                #append year and gdp value
                year.append(float(data[3]))
                values.append(float(data[4]) / 10**10)
                
                #Add country to countries plotted list.
                country = data[1] + " " + data[0]
                if country not in countries_plotted:
                    countries_plotted.append(data[1] + " " + data[0])
                continue
        else:
            if data[0] in list_countries:
                year.append(float(data[2]))
                values.append(float(data[3]) / 10**10)
                
                if data[0] not in countries_plotted:
                    countries_plotted.append(data[0])
                continue
        #Plot data 
        plt.plot(year, values)
        #Reset list of values and years for next item in the countries list.
        values = list()
        year = list()

    #Labling Plot graph.
    plt.legend(countries_plotted)
    plt.title("Oscar Lopez's GDP Plot")
    plt.xlabel('Year')
    plt.ylabel('GDP')
    
    #Save the graph
    plt.savefig('Oscar_Lopez_GDP_Plot.png')
    #Show Plot graph.
    plt.show()
    #Cleanup
    fopen.close()
        
        
""" Main Program """
list_countries = ['United States', 'China', 'European Union']
plot_data(list_countries)
